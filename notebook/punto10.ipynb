# %%
import sys
import os
sys.path.append(os.path.abspath('../src'))
from Function10 import analizarRounds
from Function10 import imprimirOrdenado
rounds = [
{
'Shadow': {'kills': 2, 'assists': 1, 'deaths': True},
'Blaze': {'kills': 1, 'assists': 0, 'deaths': False},
'Viper': {'kills': 1, 'assists': 2, 'deaths': True},
'Frost': {'kills': 0, 'assists': 1, 'deaths': False},
'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
},
{
'Shadow': {'kills': 0, 'assists': 2, 'deaths': False},
'Blaze': {'kills': 2, 'assists': 0, 'deaths': True},
'Viper': {'kills': 1, 'assists': 1, 'deaths': False},
'Frost': {'kills': 2, 'assists': 1, 'deaths': True},
'Reaper': {'kills': 0, 'assists': 1, 'deaths': False}
},
{
'Shadow': {'kills': 1, 'assists': 0, 'deaths': False},
'Blaze': {'kills': 2, 'assists': 2, 'deaths': True},
'Viper': {'kills': 1, 'assists': 1, 'deaths': True},
'Frost': {'kills': 0, 'assists': 1, 'deaths': False},
'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
},
{
'Shadow': {'kills': 2, 'assists': 1, 'deaths': False},
'Blaze': {'kills': 1, 'assists': 0, 'deaths': True},
'Viper': {'kills': 0, 'assists': 2, 'deaths': False},
'Frost': {'kills': 1, 'assists': 1, 'deaths': True},
'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
},
{
'Shadow': {'kills': 1, 'assists': 2, 'deaths': True},
'Blaze': {'kills': 0, 'assists': 1, 'deaths': False},
'Viper': {'kills': 2, 'assists': 0, 'deaths': True},
'Frost': {'kills': 1, 'assists': 1, 'deaths': False},
'Reaper': {'kills': 1, 'assists': 1, 'deaths': True}
}
]
resultados = [{
'Shadow': {'kills': 0, 'assists': 0, 'deaths': 0, 'MVPs': 0, 'puntos': 0},
'Blaze': {'kills': 0, 'assists': 0, 'deaths': 0, 'MVPs': 0, 'puntos': 0},
'Viper': {'kills': 0, 'assists': 0, 'deaths': 0, 'MVPs': 0,  'puntos': 0},
'Frost': {'kills': 0, 'assists': 0, 'deaths': 0, 'MVPs': 0, 'puntos': 0},
'Reaper': {'kills': 0, 'assists': 0, 'deaths': 0, 'MVPs': 0, 'puntos': 0}
}
 ]
resultados = analizarRounds(rounds,resultados)
print("tabla final de valores: ")
print()
imprimirOrdenado(resultados)
# Out:
# ronda: 1
# Shadow: {'kills': 2, 'assists': 1, 'deaths': 1, 'MVPs': 1, 'puntos': 6}
# Viper: {'kills': 1, 'assists': 2, 'deaths': 1, 'MVPs': 0, 'puntos': 4}
# Reaper: {'kills': 1, 'assists': 1, 'deaths': 0, 'MVPs': 0, 'puntos': 4}
# Blaze: {'kills': 1, 'assists': 0, 'deaths': 0, 'MVPs': 0, 'puntos': 3}
# Frost: {'kills': 0, 'assists': 1, 'deaths': 0, 'MVPs': 0, 'puntos': 1}
# el MVP en esta ronda es: Shadow
#
# ronda: 2
# Shadow: {'kills': 2, 'assists': 3, 'deaths': 1, 'MVPs': 1, 'puntos': 8}
# Blaze: {'kills': 3, 'assists': 0, 'deaths': 1, 'MVPs': 0, 'puntos': 8}
# Viper: {'kills': 2, 'assists': 3, 'deaths': 1, 'MVPs': 0, 'puntos': 8}
# Frost: {'kills': 2, 'assists': 2, 'deaths': 1, 'MVPs': 1, 'puntos': 7}
# Reaper: {'kills': 1, 'assists': 2, 'deaths': 0, 'MVPs': 0, 'puntos': 5}
# el MVP en esta ronda es: Frost
#
# ronda: 3
# Blaze: {'kills': 5, 'assists': 2, 'deaths': 2, 'MVPs': 1, 'puntos': 15}
# Shadow: {'kills': 3, 'assists': 3, 'deaths': 1, 'MVPs': 1, 'puntos': 11}
# Viper: {'kills': 3, 'assists': 4, 'deaths': 2, 'MVPs': 0, 'puntos': 11}
# Reaper: {'kills': 2, 'assists': 3, 'deaths': 0, 'MVPs': 0, 'puntos': 9}
# Frost: {'kills': 2, 'assists': 3, 'deaths': 1, 'MVPs': 1, 'puntos': 8}
# el MVP en esta ronda es: Blaze
#
# ronda: 4
# Shadow: {'kills': 5, 'assists': 4, 'deaths': 1, 'MVPs': 2, 'puntos': 18}
# Blaze: {'kills': 6, 'assists': 2, 'deaths': 3, 'MVPs': 1, 'puntos': 17}
# Viper: {'kills': 3, 'assists': 6, 'deaths': 2, 'MVPs': 0, 'puntos': 13}
# Reaper: {'kills': 3, 'assists': 4, 'deaths': 0, 'MVPs': 0, 'puntos': 13}
# Frost: {'kills': 3, 'assists': 4, 'deaths': 2, 'MVPs': 1, 'puntos': 11}
# el MVP en esta ronda es: Shadow
#
# ronda: 5
# Shadow: {'kills': 6, 'assists': 6, 'deaths': 2, 'MVPs': 2, 'puntos': 22}
# Blaze: {'kills': 6, 'assists': 3, 'deaths': 3, 'MVPs': 1, 'puntos': 18}
# Viper: {'kills': 5, 'assists': 6, 'deaths': 3, 'MVPs': 1, 'puntos': 18}
# Reaper: {'kills': 4, 'assists': 5, 'deaths': 1, 'MVPs': 0, 'puntos': 16}
# Frost: {'kills': 4, 'assists': 5, 'deaths': 2, 'MVPs': 1, 'puntos': 15}
# el MVP en esta ronda es: Viper
#
# tabla final de valores:
#
# Shadow: {'kills': 6, 'assists': 6, 'deaths': 2, 'MVPs': 2, 'puntos': 22}
# Blaze: {'kills': 6, 'assists': 3, 'deaths': 3, 'MVPs': 1, 'puntos': 18}
# Viper: {'kills': 5, 'assists': 6, 'deaths': 3, 'MVPs': 1, 'puntos': 18}
# Reaper: {'kills': 4, 'assists': 5, 'deaths': 1, 'MVPs': 0, 'puntos': 16}
# Frost: {'kills': 4, 'assists': 5, 'deaths': 2, 'MVPs': 1, 'puntos': 15}
